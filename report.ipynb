# %%
pip install pytesseract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.1.1; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\ProgramData\Anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import pytesseract
from PIL import Image

# %%
image = Image.open(r'C:\Users\DELL PC\new_app\a.png')

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=654x605 at 0x1FAF1ECAA58>

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files (x86)\Tesseract-OCR\tesseract.exe"
text_source = pytesseract.image_to_string(image)
# print(type(text_source))
# print(len(text_source))
for i in range (len(text_source)):
     print(text_source[i])
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# B
# l
# o
# o
# d
#
# l
# e
# s
# t
#
# R
# e
# s
# u
# l
# t
#
# N
# o
# r
# m
# a
# l
#
# V
# a
# l
# u
# e
#
#
# W
# B
# C
# s
#
# (
# b
# i
# l
# l
# i
# o
# n
# /
# L
# )
#
# 8
# .
# 0
# 0
#
# 3
# .
# 5
#
# t
# o
#
# 1
# 0
# .
# 5
#
#
# N
# e
# u
# t
# r
# o
# p
# h
# i
# l
# s
#
# (
# %
# )
#
# 6
# 2
#
# 4
# 0
#
# t
# o
#
# 7
# 0
#
#
# L
# y
# m
# p
# h
# o
# c
# y
# t
# e
# s
#
# (
# %
# )
#
# 2
# 8
#
# 2
# 5
#
# t
# o
#
# 4
# 5
#
#
# M
# o
# n
# o
# c
# y
# t
# e
# s
#
# (
# %
# )
#
# 1
# 0
#
# 2
#
# t
# o
#
# 8
#
#
# E
# o
# s
# i
# n
# o
# p
# h
# i
# l
# s
#
# (
# %
# )
#
# 1
#
# 1
#
# t
# o
#
# 5
#
#
# B
# a
# s
# o
# p
# h
# i
# l
# s
#
# (
# %
# )
#
# 0
#
# 0
#
# t
# o
#
# 1
#
#
# R
# B
# C
# s
#
# (
# t
# r
# i
# l
# l
# i
# o
# n
# /
# L
# )
#
# 3
# .
# 8
# 4
#
# 4
# .
# 3
#
# t
# o
#
# 5
# .
# 7
#
#
# H
# b
#
# (
# g
# /
# d
# L
# )
#
# 1
# 1
# .
# 7
#
# 1
# 3
#
# t
# o
#
# 1
# ...

# %%
print(text_source[0])
